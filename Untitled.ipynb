# %%
import pandas as pd
import numpy as np
from sklearn import svm,preprocessing
from tqdm import tqdm

# %%
a1=pd.read_csv('testing.csv')
a2=pd.read_csv('trainning.csv')

# %%
accept1=[]
accept2=[]

for key in a1.keys():
    if len(np.unique(a1[key]))>1:
        accept1.append(key)
for key in a2.keys():
    if len(np.unique(a2[key]))>1:
        accept2.append(key)

# %%
def normarlize(length):
    return (length-length.mean())/length.std(),length.mean(),length.std()

# %%
b=list()
des=list()
for key in tqdm(sorted(accept2)):
    if a2[key].dtype=='int64' or a2[key].dtype=='float64':
        nm,mean,std=normarlize(a2[key])
        nm=np.expand_dims(nm.tolist(),0)
        des.append([mean,std])
    elif a2[key].dtype=='O':
        uni=a2[key].unique()
        l=len(uni)
        if '-1' in uni:
            l-=1
        nm=np.zeros((len(a2[key]),l))
        uni=np.delete(uni,np.argwhere(uni=='-1'))
        uni=dict(zip(uni,list(range(len(uni)))))
        des.append(uni)
        for i,n in enumerate(a2[key]):
            try:
                nm[i,uni[n]]=1
            except:
                continue  
        nm=nm.T
    else:
        continue
    b.append(nm)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 105.91it/s]

# %%
b[4]
# Out:
# array([[-0.64591725,  1.54816057, -0.64591725, ..., -0.64591725,
#         -0.64591725, -0.64591725]])

# %%
des
# Out:
# [{'application/x-www-form-urlencoded': 0},
#  [-0.6639651513682311, 0.5230356439912487],
#  [-3.275198558912634e-05, 0.005722888189897036],
#  [-0.41121755506427576, 0.9115446941561371],
#  [-0.7056087775321379, 0.4557723470780686],
#  [0.4652084416338671, 0.06370626152982117],
#  [0.11408583318152604, 0.050653580160376015],
#  [-0.6707302230489728, 0.520041248615934],
#  {'jsp': 0,
#   'gif~': 1,
#   'asp': 2,
#   'gif': 3,
#   'htm': 4,
#   'BAK': 5,
#   'jpg/asf-logo-wide.gif.old': 6,
#   'jsp.INC': 7,
#   'cnf': 8,
#   'jsp.OLD': 9,
#   'cfm': 10,
#   'jsp.Old': 11,
#   'jsp.bak': 12,
#   'htr': 13,
#   'bak': 14,
#   'jsp/6909030637832563290.jsp.Old': 15,
#   'jpg.old': 16,
#   'gif.old': 17,
#   'gif.BAK': 18,
#   'exe': 19,
#   'old': 20,
#   'jsp/asf-logo-wide.java': 21,
#   'inc': 22,
#   'jpg/6909030637832563290.jsp.old': 23,
#   'jsp/4861362529278789730.INC': 24,
#   'jsp/asf-logo-wide.gif/.old': 25,
#   'gif.OLD': 26,
#   'java': 27,
#   'jsp/asf-logo-wide.gif~': 28,
#   'jsp/6909030637832563290.jsp.INC': 29,
#   'gif/.Old': 30,
#   'css/6909030637832563290.jsp': 31,
#   'jsp/.BAK': 32,
#   'css.INC': 33,
#   'jpg.Inc': 34,
#   'html': 35,
#   'jpg/asf-logo-wide.OLD': 36,
#   'jsp/asf-logo-wide.gif/.Old': 37,
#   'jsp.old': 38,
#   'Inc': 39,
#   'jsp/asf-logo-wide.gif': 40,
#   'nsf': 41,
#   'gif/6909030637832563290.jsp.OLD': 42,
#   'jsp/6909030637832563290.jsp.old': 43,
#   'css.Bak': 44,
#   'Bak': 45,
#   'jsp.java': 46,
#   'gif/.old': 47,
#   'jsp/4861362529278789730.java': 48,
#   'jsp.Bak': 49,
#   'portal': 50,
#   'dll': 51,
#   'jsp/.inc': 52,
#   'jsp/4861362529278789730.OLD': 53,
#   'gif/.OLD': 54,
#   'gif.INC': 55,
#   'gif.Old': 56,
#   'do': 57,
#   'gif.Inc': 58,
#   'gif.bak': 59,
#   'jsp.inc': 60,
#   'INC': 61,
#   'jsp/asf-logo-wide.gif.Old': 62,
#   'jsp.Inc': 63,
#   'gif/4861362529278789730.bak': 64,
#   'OLD': 65,
#   'Old': 66,
#   'css/6909030637832563290.jsp.INC': 67,
#   'btr': 68,
#   'jsp/4861362529278789730.Old': 69,
#   'jsp/asf-logo-wide.gif.inc': 70,
#   'jsp/6909030637832563290.jsp~': 71,
#   'gif/.INC': 72,
#   'jsp/asf-logo-wide.Bak': 73,
#   'jsp/.old': 74,
#   'jpg/asf-logo-wide.gif/.Old': 75,
#   'jsp.BAK': 76,
#   'gif/.BAK': 77,
#   'css/.INC': 78,
#   'jsp/.INC': 79,
#   'jpg/4861362529278789730.INC': 80,
#   'jsp/asf-logo-wide.gif/.INC': 81,
#   'jsp/asf-logo-wide.bak': 82,
#   'gif/asf-logo-wide.gif/.BAK': 83,
#   'jsp/asf-logo-wide.gif.old': 84,
#   'gif/.Inc': 85,
#   'jsp/4861362529278789730.Bak': 86,
#   'gif/4861362529278789730.BAK': 87,
#   'gif/asf-logo-wide.gif/.OLD': 88,
#   'gif/6909030637832563290.jsp': 89,
#   'jsp~': 90,
#   'jsp/4861362529278789730.Inc': 91,
#   'gif.java': 92,
#   'gif/.Bak': 93,
#   'jpg/asf-logo-wide.gif/.OLD': 94,
#   'gif.inc': 95,
#   'jpg.inc': 96,
#   'jsp/asf-logo-wide.gif/.OLD': 97,
#   'jsp/asf-logo-wide.BAK': 98,
#   'jsp/6909030637832563290.jsp.java': 99,
#   'jpg.INC': 100,
#   'jsp/6909030637832563290.jsp': 101,
#   'jsp/6909030637832563290.jsp.inc': 102,
#   'xml': 103,
#   'css/asf-logo-wide.gif.Old': 104,
#   'txt': 105,
#   'jsp/asf-logo-wide.gif.OLD': 106,
#   'properties': 107,
#   'css.BAK': 108,
#   'jsp/4861362529278789730.BAK': 109,
#   'jpg/4861362529278789730.OLD': 110,
#   'gif/asf-logo-wide.Bak': 111,
#   'jpg/asf-logo-wide.Bak': 112,
#   'gif/asf-logo-wide.gif/.Old': 113,
#   'jsp/asf-logo-wide.gif.BAK': 114,
#   'jsp/asf-logo-wide.gif.INC': 115,
#   'jsp/asf-logo-wide.gif.Bak': 116,
#   'jsp/4861362529278789730.bak': 117,
#   'jpg/6909030637832563290.jsp': 118,
#   'jpg~': 119,
#   'jsp/.java': 120,
#   'box': 121,
#   'jpg/4861362529278789730.BAK': 122,
#   'jsp/.OLD': 123,
#   'jsp/asf-logo-wide.gif/.bak': 124,
#   'jsp/4861362529278789730.old': 125,
#   'gif/4861362529278789730.OLD': 126,
#   'jpg/4861362529278789730.bak': 127,
#   'css~': 128,
#   'jsp/asf-logo-wide.gif.bak': 129,
#   'jpg/asf-logo-wide.gif/.java': 130,
#   'jpg/.old': 131,
#   'jpg.BAK': 132,
#   'gif/.java': 133,
#   'jsp/.bak': 134,
#   'jsp/6909030637832563290.jsp.Bak': 135,
#   'jsp/asf-logo-wide.INC': 136,
#   'jpg/asf-logo-wide.gif': 137,
#   'jpg.bak': 138,
#   'gif.Bak': 139,
#   'gif/6909030637832563290.jsp.Old': 140,
#   'gif/.inc': 141,
#   'jsp/asf-logo-wide.Old': 142,
#   'jsp/6909030637832563290.jsp.Inc': 143,
#   'jpg/asf-logo-wide.bak': 144,
#   'gif/asf-logo-wide.gif.Inc': 145,
#   'jpg.OLD': 146,
#   'jsp/asf-logo-wide.OLD': 147,
#   'css/asf-logo-wide.gif': 148,
#   'jpg.Old': 149,
#   'gif/asf-logo-wide.java': 150,
#   'css/asf-logo-wide.gif/.old': 151,
#   'gif/asf-logo-wide.inc': 152,
#   'gif/4861362529278789730.Inc': 153,
#   'gif/asf-logo-wide.gif/.old': 154,
#   'gif/asf-logo-wide.gif.inc': 155,
#   'jsp/asf-logo-wide.Inc': 156,
#   'jsp/asf-logo-wide.gif/.BAK': 157,
#   'jpg.Bak': 158,
#   'gif/asf-logo-wide.gif': 159,
#   'jpg/asf-logo-wide.gif/.Bak': 160,
#   'jsp/.Bak': 161,
#   'css/asf-logo-wide.gif/.BAK': 162,
#   'jpg.java': 163,
#   'jsp/.Old': 164,
#   'gif/6909030637832563290.jsp~': 165,
#   'jsp/asf-logo-wide.gif/.Bak': 166,
#   'jpg/asf-logo-wide.gif/.Inc': 167,
#   'gif/4861362529278789730.Bak': 168,
#   'jpg/asf-logo-wide.gif.BAK': 169,
#   'css/.old': 170,
#   'jsp/asf-logo-wide.gif/.Inc': 171,
#   'jpg/6909030637832563290.jsp.Old': 172,
#   'css/.Inc': 173,
#   'gif/asf-logo-wide.gif~': 174,
#   'gif/4861362529278789730.old': 175,
#   'gif/asf-logo-wide.gif/.inc': 176,
#   'gif/asf-logo-wide.gif/.bak': 177,
#   'jpg/4861362529278789730.Old': 178,
#   'jsp/6909030637832563290.jsp.BAK': 179,
#   'jsp/.Inc': 180,
#   'jsp/asf-logo-wide.gif.java': 181,
#   'css/.Old': 182,
#   'css/.Bak': 183,
#   'jpg/6909030637832563290.jsp.Bak': 184,
#   'jsp/4861362529278789730.inc': 185,
#   'jsp/6909030637832563290.jsp.OLD': 186,
#   'css.OLD': 187,
#   'jpg/.Inc': 188,
#   'gif/asf-logo-wide.gif/.INC': 189,
#   'jsp/asf-logo-wide.gif.Inc': 190,
#   'gif/.bak': 191,
#   'jpg/.inc': 192,
#   'jsp/asf-logo-wide.inc': 193,
#   'jpg/asf-logo-wide.gif.Inc': 194,
#   'css.bak': 195,
#   'gif/asf-logo-wide.gif/.Inc': 196,
#   'gif/4861362529278789730.Old': 197,
#   'jpg/asf-logo-wide.Inc': 198,
#   'gif/asf-logo-wide.gif.OLD': 199,
#   'gif/asf-logo-wide.INC': 200,
#   'css.inc': 201,
#   'jsp/asf-logo-wide.old': 202,
#   'jpg/.java': 203,
#   'jsp/6909030637832563290.jsp.bak': 204,
#   'jsp/asf-logo-wide.gif/.inc': 205,
#   'jpg/asf-logo-wide.gif/.old': 206,
#   'jpg/asf-logo-wide.java': 207,
#   'gif/6909030637832563290.jsp.inc': 208,
#   'css.Old': 209,
#   'gif/6909030637832563290.jsp.old': 210,
#   'jpg/asf-logo-wide.gif/.inc': 211,
#   'gif/asf-logo-wide.gif/.Bak': 212,
#   'jpg/asf-logo-wide.gif.inc': 213,
#   'jpg/asf-logo-wide.gif~': 214,
#   'gif/asf-logo-wide.gif.bak': 215,
#   'jpg/6909030637832563290.jsp.Inc': 216,
#   'jpg/asf-logo-wide.gif/.BAK': 217,
#   'css/asf-logo-wide.gif/.Old': 218,
#   'jpg/4861362529278789730.inc': 219,
#   'jpg/6909030637832563290.jsp.OLD': 220,
#   'jpg/6909030637832563290.jsp.inc': 221,
#   'css.old': 222,
#   'gif/4861362529278789730.INC': 223,
#   'jsp/asf-logo-wide.gif/.java': 224,
#   'jpg/asf-logo-wide.Old': 225,
#   'css/asf-logo-wide.BAK': 226,
#   'gif/6909030637832563290.jsp.Bak': 227,
#   'css.java': 228,
#   'css/asf-logo-wide.gif.inc': 229,
#   'jpg/asf-logo-wide.gif.Bak': 230,
#   'jpg/.BAK': 231,
#   'gif/asf-logo-wide.Inc': 232,
#   'gif/asf-logo-wide.old': 233,
#   'jpg/asf-logo-wide.gif.bak': 234,
#   'jpg/asf-logo-wide.gif.OLD': 235,
#   'gif/6909030637832563290.jsp.Inc': 236,
#   'jpg/6909030637832563290.jsp.BAK': 237,
#   'jpg/6909030637832563290.jsp~': 238,
#   'gif/asf-logo-wide.gif.old': 239,
#   'jpg/.OLD': 240,
#   'css/6909030637832563290.jsp.inc': 241,
#   'css/asf-logo-wide.gif/.bak': 242,
#   'gif/asf-logo-wide.gif.Bak': 243,
#   'jpg/4861362529278789730.old': 244,
#   'css/asf-logo-wide.Old': 245,
#   'gif/asf-logo-wide.gif.INC': 246,
#   'gif/4861362529278789730.java': 247,
#   'css/asf-logo-wide.gif/.Inc': 248,
#   'css/.inc': 249,
#   'gif/4861362529278789730.inc': 250,
#   'css/asf-logo-wide.gif.INC': 251,
#   'gif/asf-logo-wide.Old': 252,
#   'gif/asf-logo-wide.gif.Old': 253,
#   'jpg/4861362529278789730.Bak': 254,
#   'css/4861362529278789730.inc': 255,
#   'jpg/.bak': 256,
#   'css/asf-logo-wide.java': 257,
#   'gif/asf-logo-wide.bak': 258,
#   'jpg/6909030637832563290.jsp.java': 259,
#   'css/4861362529278789730.old': 260,
#   'css/6909030637832563290.jsp.Old': 261,
#   'jpg/.Old': 262,
#   'css': 263,
#   'jpg': 264},
#  [0.9781708016048473, 0.14612677430817214],
#  {'close': 0},
#  [0.9999672480144108, 0.005722888189897036],
#  [0.2943912224678621, 0.4557723470780686],
#  [0.2943912224678621, 0.4557723470780686],
#  [31.23129452223041, 75.95940891447258],
#  [4.9998034880864655, 0.03433732913938222],
#  [-0.05096208957668059, 1.5050104425626232],
#  [9.009301563907313, 15.49625980065433],
#  [81.32535822484238, 75.54706564682715],
#  [31.341979857528862, 75.13448763861422],
#  [-0.49912855693062874, 0.7787962733082504],
#  [0.9999344960288218, 0.011445776379794072],
#  [-0.7056087775321379, 0.4557723470780686],
#  [-0.4469013396058348, 0.8562995611769773],
#  [0.5115357444126446, 0.06370626152982119],
#  [0.7212704575709316, 0.0531700059857103],
#  [-0.5094810572893661, 0.7739075128372928],
#  {'GET': 0, 'POST': 1, 'PUT': 2},
#  [-0.7056087775321379, 0.4557723470780686],
#  [-3.275198558912634e-05, 0.005722888189897036],
#  [-0.7056087775321379, 0.4557723470780686],
#  [-0.7056087775321379, 0.4557723470780686],
#  [0.0008314165492351005, 0.0032385486010314555],
#  [-0.7103525846009888, 0.4550469620999993],
#  [0.09509384353648664, 0.007596706973602479],
#  [10.588749692950135, 0.9115838135428557],
#  [3.2441824285597316, 4.554008682904909],
#  [4.01141406697781, 0.47464613052504423],
#  [-0.41121755506427576, 0.9115446941561371],
#  [0.9999344960288218, 0.011445776379794072],
#  [-0.41121755506427576, 0.9115446941561371],
#  [-0.41121755506427576, 0.9115446941561371],
#  [0.999168583450765, 0.0032385486010314537],
#  [-0.4245528440406225, 0.9040094841358032],
#  [0.9049061564635135, 0.0075967069736024495]]

# %%
uni=np.delete(uni,np.argwhere(uni=='-1'))

# %%
uni=dict(zip(uni,list(range(len(uni)))))

# %%
nm=np.zeros((len(a2.content_type),l))
for i,n in enumerate(a2.content_type):
    try:
        nm[i,uni[n]]=1
    except:
        continue
